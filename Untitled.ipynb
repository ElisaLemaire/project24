# %%
Chrfinder/
├── assets/
│   ├── Caf_Ace_Asp.gif
│   └── Image_Chrfinder.webp
├── data/
│   └── README.md
├── docs/
│   ├── docs_out/
│   │   ├── _modules/
│   │   │   ├── chrfinder/
│   │   │   │   └── example_module.html
│   │   │   └── index.html
│   │   ├── _sources/
│   │   │   ├── api/
│   │   │   │   ├── chrfinder.rst.txt
│   │   │   │   └── modules.rst.txt
│   │   │   └── index.md.txt
│   │   ├── _static/
│   │   │   ├── basic.css
│   │   │   ├── check-solid.svg
│   │   │   ├── clipboard.min.js
│   │   │   ├── copy-button.svg
│   │   │   ├── copybutton.css
│   │   │   ├── copybutton.js
│   │   │   ├── copybutton_funcs.js
│   │   │   ├── debug.css
│   │   │   ├── doctools.js
│   │   │   ├── documentation_options.js
│   │   │   ├── file.png
│   │   │   ├── language_data.js
│   │   │   ├── minus.png
│   │   │   ├── plus.png
│   │   │   ├── pygments.css
│   │   │   ├── scripts/
│   │   │   │   ├── furo-extensions.js
│   │   │   │   ├── furo.js
│   │   │   │   ├── furo.js.LICENSE.txt
│   │   │   │   └── furo.js.map
│   │   │   ├── searchtools.js
│   │   │   ├── skeleton.css
│   │   │   ├── sphinx_highlight.js
│   │   │   └── styles/
│   │   │       ├── furo-extensions.css
│   │   │       ├── furo-extensions.css.map
│   │   │       ├── furo.css
│   │   │       └── furo.css.map
│   │   ├── api/
│   │   │   ├── chrfinder.html
│   │   │   └── modules.html
│   │   ├── genindex.html
│   │   ├── index.html
│   │   ├── objects.inv
│   │   ├── py-modindex.html
│   │   ├── search.html
│   │   └── searchindex.js
│   └── source/
│       ├── _static/
│       ├── api/
│       │   ├── Chrfinder.rst
│       │   └── modules.rst
│       ├── conf.py
│       └── index.md
├── LICENSE
├── notebooks/
│   ├── __init__.py
│   ├── __pycache__/
│   │   ├── classify.cpython-310.pyc
│   │   └── pka_lookup.cpython-310.pyc
│   ├── classify.py
│   ├── dsantos.ipynb
│   ├── get_df_infos.py
│   ├── pka_lookup.py
│   ├── Properties.ipynb
│   └── search_pka.py
├── project_report.ipynb
├── pyproject.toml
├── pytest
├── python
├── README.md
├── report.ipynb
├── sphinx-build
├── src/
│   ├── __pycache__/
│   │   ├── Chrfinder.cpython-310.pyc
│   │   ├── classify.cpython-310.pyc
│   │   ├── pka_lookup.cpython-310.pyc
│   │   └── pubchemprops.cpython-310.pyc
│   └── Chrfinder/
│       ├── 22.05 Anthony.ipynb
│       ├── __init__.py
│       ├── __pycache__/
│       │   ├── __init__.cpython-310.pyc
│       │   ├── Chrfinder.cpython-310.pyc
│       │   ├── pka_lookup.cpython-310.pyc
│       │   └── pubchemprops.cpython-310.pyc
│       ├── Chrfinder.py
│       ├── chroma/
│       │   └── codecorrected.ipynb
│       ├── classify.py
│       ├── example_module.py
│       ├── pka_lookup.py
│       ├── pubchemprops.py
│       └── search_pka.py
├── tests/
│   ├── __pycache__/
│   │   ├── Test_anthony.cpython-310-pytest-8.2.1.pyc
│   │   └── test_complete.cpython-310-pytest-8.2.1.pyc
│   └── test_complete.py
├── tox.ini
└── Untitled.ipynb
